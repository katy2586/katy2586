# %% [markdown]
# <a href="https://colab.research.google.com/github/katy2586/katy2586/blob/main/DZ6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/gdrive', force_remount=True)   #у меня так и не получилось закгрузить датасет Титаник, подозреваю, что дело в кавычках в именах пассажиров. везде - Nan
                                                      #пробовала index_col, encoding ='cp1251', quoting=3.   Не получается
                                                      #более-менее quoting=3 срабатывает, NaN исчезает, но все столбцы съезжают
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import files
uploaded = files.upload ()
# Out:
#      <input type="file" id="files-ab2aafce-2b43-4609-8cd5-69a735a6e3cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab2aafce-2b43-4609-8cd5-69a735a6e3cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel ('Largest Companies in the World.xlsx')
df
# Out:
#       Global Rank                     Company  Sales ($billion)  \
# 0               1                        ICBC             134.8
# 1               2     China Construction Bank             113.1
# 2               3              JPMorgan Chase             108.2
# 3               4            General Electric             147.4
# 4               5                 Exxon Mobil             420.7
# ...           ...                         ...               ...
# 1919         1995              Tractor Supply               4.7
# 1920         1996                  San-Ai Oil               0.5
# 1921         1996                   UOL Group               0.9
# 1922         1998     Interconexion Electrica               2.4
# 1923         1999  Old Republic International               5.0
#
#       Profits ($billion)  Assets ($billion)  Market Value ($billion)  \
# 0                   37.8             2813.5                    237.3
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.bar (df['Continent'], df ['Market Value ($billion)'])
plt.xlabel ('Континент')
plt.ylabel ('Объем рынка')
# Out:
# Text(0, 0.5, 'Объем рынка')
